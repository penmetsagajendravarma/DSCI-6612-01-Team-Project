# %% [markdown]
# ## 1 · Setup & Imports
# Installs Gymnasium 0.29, PyGame, Stable‑Baselines3 (+ QRDQN) and TensorBoard,
# then imports all libraries and defines global screen constants.

# %%
# !pip install gymnasium==0.29.1 pygame stable-baselines3[extra] sb3-contrib tensorboard --quiet

import gymnasium as gym, numpy as np, random, pygame, cv2, torch, time, math
from gymnasium import spaces
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import BaseCallback
from sb3_contrib import QRDQN
from torch import nn
pygame.init()

SCREEN_W, SCREEN_H = 288, 512
BASEY              = int(SCREEN_H*0.79)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 50.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 107.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.

# %% [markdown]
# ## 2 · Environment Definition
# * `FlappyCore` implements Flappy‑Bird physics and reward logic
# * `FlappyPixelEnv` wraps it as a Gymnasium Env, renders 84 × 84 grayscale
#   frames, and stacks 4 frames for temporal context (+0.2 living bonus).

# %%
def new_pipe(gap=100):
    gap_y = random.randint(120, 280)
    x = SCREEN_W + 10
    return [{'x': x, 'y': gap_y-320}, {'x': x, 'y': gap_y+gap}]

class FlappyCore:
    def __init__(self, gap=100): self.gap=gap; self.reset()
    def reset(self):
        self.bird_y, self.vel_y = SCREEN_H//2, -9
        self.pipes = list(new_pipe(self.gap)); self.frames=0
    def step(self, action):
        if action and self.bird_y>-24: self.vel_y = -9
        self.vel_y = min(self.vel_y+1, 10); self.bird_y += self.vel_y
        prev = self.pipes[0]['x']+52
        for p in self.pipes: p['x'] -= 4
        if self.pipes[-1]['x'] < SCREEN_W-150: self.pipes.extend(new_pipe(self.gap))
        if self.pipes[0]['x'] < -52: self.pipes=self.pipes[2:]
        curr = self.pipes[0]['x']+52; up, lo = self.pipes[0], self.pipes[1]
        term = self.bird_y+24>=BASEY or (up['x']<60<up['x']+52 and not(up['y']+320<self.bird_y<lo['y']-24))
        reward = -1. if term else 0.
        if not term and prev>=60>curr: reward = 1.
        self.frames += 1
        return reward, term

class FlappyPixelEnv(gym.Env):
    metadata = {}
    def __init__(self, frame_stack=4, gap=100):
        self.core = FlappyCore(gap); self.fs=frame_stack
        self.stack = np.zeros((frame_stack, 84, 84), np.uint8)
        self.canvas = pygame.Surface((SCREEN_W,SCREEN_H))
        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(0,255,(frame_stack,84,84),np.uint8)
    def _render84(self):
        self.canvas.fill((135,206,250))
        for i in range(0,len(self.core.pipes),2):
            up, lo = self.core.pipes[i], self.core.pipes[i+1]
            pygame.draw.rect(self.canvas,(0,255,0),pygame.Rect(up['x'],up['y'],52,320))
            pygame.draw.rect(self.canvas,(0,255,0),pygame.Rect(lo['x'],lo['y'],52,320))
        pygame.draw.rect(self.canvas,(255,255,0),pygame.Rect(60,self.core.bird_y,34,24))
        img = pygame.surfarray.array3d(self.canvas).swapaxes(0,1)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        return cv2.resize(gray,(84,84),cv2.INTER_AREA)
    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed); self.core.reset()
        f = self._render84(); self.stack[:] = f
        return self.stack.copy(), {}
    def step(self, action):
        r, term = self.core.step(int(action))
        f = self._render84(); self.stack = np.roll(self.stack,-1,0); self.stack[-1]=f
        r += 0.2                     # living bonus
        return self.stack.copy(), r, term, False, {}

# %% [markdown]
# ## 3 · CNN Feature Extractors
# * **AtariExtractor** – classic 3‑conv Atari architecture (baseline)
# * **InceptionExtractor** – replaces middle layers with a lightweight
#   Inception‑A block for multi‑scale feature learning.

# %%
import torch
from torch import nn
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class AtariExtractor(BaseFeaturesExtractor):
    def __init__(self, obs_space, features_dim=512):
        super().__init__(obs_space, features_dim)
        n_ch = obs_space.shape[0]
        self.conv = nn.Sequential(
            nn.Conv2d(n_ch,32,8,4), nn.ReLU(),
            nn.Conv2d(32,64,4,2), nn.ReLU(),
            nn.Conv2d(64,64,3,1), nn.ReLU(),
            nn.Flatten())
        with torch.no_grad():
            n_flat = self.conv(torch.as_tensor(obs_space.sample()[None]).float()).shape[1]
        self.fc = nn.Sequential(nn.Linear(n_flat, features_dim), nn.ReLU())
        self._features_dim = features_dim
    def forward(self,x): return self.fc(self.conv(x/255.0))

class InceptionA(nn.Module):
    def __init__(self,in_c,out_c=96):
        super().__init__()
        k = out_c//3
        self.b1 = nn.Conv2d(in_c,k,1)
        self.b3 = nn.Sequential(nn.Conv2d(in_c,k,1),nn.ReLU(),
                                nn.Conv2d(k,k,3,1,1))
        self.b5 = nn.Sequential(nn.Conv2d(in_c,k,1),nn.ReLU(),
                                nn.Conv2d(k,k,5,1,2))
    def forward(self,x): return torch.cat((self.b1(x),self.b3(x),self.b5(x)),1)

class InceptionExtractor(BaseFeaturesExtractor):
    def __init__(self, obs_space, features_dim=512):
        super().__init__(obs_space, features_dim)
        n_ch = obs_space.shape[0]
        self.conv = nn.Sequential(
            nn.Conv2d(n_ch,32,8,4), nn.ReLU(),
            InceptionA(32,96), nn.ReLU(),
            nn.Conv2d(96,64,3,1), nn.ReLU(),
            nn.Flatten())
        with torch.no_grad():
            n_flat = self.conv(torch.as_tensor(obs_space.sample()[None]).float()).shape[1]
        self.fc = nn.Sequential(nn.Linear(n_flat, features_dim), nn.ReLU())
        self._features_dim = features_dim
    def forward(self,x): return self.fc(self.conv(x/255.0))

# %% [markdown]
# ## 4 · Training Callback
# `FirstPipeCB` logs the simulator step at which the first +1 pipe‑pass reward
# is observed, giving a sample‑efficiency metric.

# %%
from stable_baselines3.common.logger import KVWriter

class FirstPipeCB(BaseCallback):
    def __init__(self): super().__init__(); self.hit=False
    def _on_step(self):
        r = self.locals["rewards"]
        if not self.hit and (r > 0.9).any():
            self.logger.record("custom/time_first_pipe", self.num_timesteps)
            self.hit=True
        return True

# %% [markdown]
# ## 5 · Training Helper
# `train_agent()` builds a QR‑DQN with the chosen extractor, trains for 2 M
# steps, and returns the fitted model (TensorBoard logs under `tb/`).

# %%
def train_agent(extractor_cls, label, total_steps=2_000_000, gap=100):
    env = Monitor(FlappyPixelEnv(gap=gap))
    policy_kwargs = dict(
        features_extractor_class = extractor_cls,
        features_extractor_kwargs = dict(features_dim=512)
    )
    model = QRDQN(
        "CnnPolicy",
        env,
        policy_kwargs       = policy_kwargs,
        learning_rate       = 5e-4,
        buffer_size         = 50_000,
        learning_starts     = 5_000,
        batch_size          = 32,
        target_update_interval = 1_000,
        exploration_fraction   = 0.15,
        exploration_final_eps  = 0.10,
        gamma               = 0.99,
        verbose             = 1,
        tensorboard_log     = f"tb/{label}"
    )
    model.learn(total_timesteps=total_steps,
                callback=FirstPipeCB(),
                progress_bar=True)
    return model

# %% [markdown]
# ## 6 · Baseline – Atari CNN
# Trains the baseline QR‑DQN for 2 M steps and prints average / best pipes
# over 50 evaluation episodes.

# %%
baseline   = train_agent(AtariExtractor,     "baseline")
metrics_b  = evaluate(baseline)
print("Baseline:", metrics_b)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Logging to tb/baseline/QRDQN_1
# Output()
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.6     |
# |    n_updates        | 465206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25172    |
# |    fps              | 168      |
# |    time_elapsed     | 11060    |
# |    total_timesteps  | 1866162  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33       |
# |    n_updates        | 465290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25176    |
# |    fps              | 168      |
# |    time_elapsed     | 11062    |
# |    total_timesteps  | 1866544  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.8     |
# |    n_updates        | 465385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25180    |
# |    fps              | 168      |
# |    time_elapsed     | 11065    |
# |    total_timesteps  | 1866989  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.3     |
# |    n_updates        | 465497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25184    |
# |    fps              | 168      |
# |    time_elapsed     | 11068    |
# |    total_timesteps  | 1867533  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.8     |
# |    n_updates        | 465633   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25188    |
# |    fps              | 168      |
# |    time_elapsed     | 11071    |
# |    total_timesteps  | 1868009  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.9     |
# |    n_updates        | 465752   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25192    |
# |    fps              | 168      |
# |    time_elapsed     | 11073    |
# |    total_timesteps  | 1868338  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.7     |
# |    n_updates        | 465834   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25196    |
# |    fps              | 168      |
# |    time_elapsed     | 11076    |
# |    total_timesteps  | 1868834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.8     |
# |    n_updates        | 465958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25200    |
# |    fps              | 168      |
# |    time_elapsed     | 11078    |
# |    total_timesteps  | 1869126  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.9     |
# |    n_updates        | 466031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25204    |
# |    fps              | 168      |
# |    time_elapsed     | 11080    |
# |    total_timesteps  | 1869504  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.3     |
# |    n_updates        | 466125   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.6     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25208    |
# |    fps              | 168      |
# |    time_elapsed     | 11082    |
# |    total_timesteps  | 1869793  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.1     |
# |    n_updates        | 466198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25212    |
# |    fps              | 168      |
# |    time_elapsed     | 11085    |
# |    total_timesteps  | 1870292  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.2     |
# |    n_updates        | 466322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25216    |
# |    fps              | 168      |
# |    time_elapsed     | 11088    |
# |    total_timesteps  | 1870835  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.7     |
# |    n_updates        | 466458   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25220    |
# |    fps              | 168      |
# |    time_elapsed     | 11091    |
# |    total_timesteps  | 1871286  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.4     |
# |    n_updates        | 466571   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25224    |
# |    fps              | 168      |
# |    time_elapsed     | 11095    |
# |    total_timesteps  | 1871916  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.5     |
# |    n_updates        | 466728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25228    |
# |    fps              | 168      |
# |    time_elapsed     | 11097    |
# |    total_timesteps  | 1872258  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.7     |
# |    n_updates        | 466814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25232    |
# |    fps              | 168      |
# |    time_elapsed     | 11099    |
# |    total_timesteps  | 1872686  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 53       |
# |    n_updates        | 466921   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25236    |
# |    fps              | 168      |
# |    time_elapsed     | 11102    |
# |    total_timesteps  | 1873140  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.4     |
# |    n_updates        | 467034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25240    |
# |    fps              | 168      |
# |    time_elapsed     | 11104    |
# |    total_timesteps  | 1873516  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33.1     |
# |    n_updates        | 467128   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25244    |
# |    fps              | 168      |
# |    time_elapsed     | 11109    |
# |    total_timesteps  | 1874255  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.3     |
# |    n_updates        | 467313   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25248    |
# |    fps              | 168      |
# |    time_elapsed     | 11110    |
# |    total_timesteps  | 1874465  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30       |
# |    n_updates        | 467366   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25252    |
# |    fps              | 168      |
# |    time_elapsed     | 11112    |
# |    total_timesteps  | 1874757  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.5     |
# |    n_updates        | 467439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25256    |
# |    fps              | 168      |
# |    time_elapsed     | 11114    |
# |    total_timesteps  | 1875209  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.6     |
# |    n_updates        | 467552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25260    |
# |    fps              | 168      |
# |    time_elapsed     | 11117    |
# |    total_timesteps  | 1875666  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.8     |
# |    n_updates        | 467666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25264    |
# |    fps              | 168      |
# |    time_elapsed     | 11120    |
# |    total_timesteps  | 1876072  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.7     |
# |    n_updates        | 467767   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25268    |
# |    fps              | 168      |
# |    time_elapsed     | 11122    |
# |    total_timesteps  | 1876440  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 45.9     |
# |    n_updates        | 467859   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25272    |
# |    fps              | 168      |
# |    time_elapsed     | 11124    |
# |    total_timesteps  | 1876774  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33.4     |
# |    n_updates        | 467943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25276    |
# |    fps              | 168      |
# |    time_elapsed     | 11126    |
# |    total_timesteps  | 1877165  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 41.6     |
# |    n_updates        | 468041   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25280    |
# |    fps              | 168      |
# |    time_elapsed     | 11128    |
# |    total_timesteps  | 1877499  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.7     |
# |    n_updates        | 468124   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25284    |
# |    fps              | 168      |
# |    time_elapsed     | 11130    |
# |    total_timesteps  | 1877751  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.1     |
# |    n_updates        | 468187   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25288    |
# |    fps              | 168      |
# |    time_elapsed     | 11133    |
# |    total_timesteps  | 1878245  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 56.9     |
# |    n_updates        | 468311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25292    |
# |    fps              | 168      |
# |    time_elapsed     | 11134    |
# |    total_timesteps  | 1878530  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.9     |
# |    n_updates        | 468382   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25296    |
# |    fps              | 168      |
# |    time_elapsed     | 11136    |
# |    total_timesteps  | 1878832  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22       |
# |    n_updates        | 468457   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25300    |
# |    fps              | 168      |
# |    time_elapsed     | 11138    |
# |    total_timesteps  | 1879203  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 37.6     |
# |    n_updates        | 468550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | 19.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25304    |
# |    fps              | 168      |
# |    time_elapsed     | 11140    |
# |    total_timesteps  | 1879495  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.9     |
# |    n_updates        | 468623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25308    |
# |    fps              | 168      |
# |    time_elapsed     | 11143    |
# |    total_timesteps  | 1879972  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.1     |
# |    n_updates        | 468742   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | 19.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25312    |
# |    fps              | 168      |
# |    time_elapsed     | 11144    |
# |    total_timesteps  | 1880212  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 73.5     |
# |    n_updates        | 468802   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25316    |
# |    fps              | 168      |
# |    time_elapsed     | 11146    |
# |    total_timesteps  | 1880544  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 36.4     |
# |    n_updates        | 468885   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25320    |
# |    fps              | 168      |
# |    time_elapsed     | 11148    |
# |    total_timesteps  | 1880847  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 43.6     |
# |    n_updates        | 468961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95       |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25324    |
# |    fps              | 168      |
# |    time_elapsed     | 11152    |
# |    total_timesteps  | 1881415  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.9     |
# |    n_updates        | 469103   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25328    |
# |    fps              | 168      |
# |    time_elapsed     | 11153    |
# |    total_timesteps  | 1881677  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.9     |
# |    n_updates        | 469169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25332    |
# |    fps              | 168      |
# |    time_elapsed     | 11155    |
# |    total_timesteps  | 1881999  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 25.4     |
# |    n_updates        | 469249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25336    |
# |    fps              | 168      |
# |    time_elapsed     | 11158    |
# |    total_timesteps  | 1882495  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.8     |
# |    n_updates        | 469373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25340    |
# |    fps              | 168      |
# |    time_elapsed     | 11160    |
# |    total_timesteps  | 1882870  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33       |
# |    n_updates        | 469467   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.9     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25344    |
# |    fps              | 168      |
# |    time_elapsed     | 11163    |
# |    total_timesteps  | 1883247  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 51.3     |
# |    n_updates        | 469561   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25348    |
# |    fps              | 168      |
# |    time_elapsed     | 11166    |
# |    total_timesteps  | 1883710  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.6     |
# |    n_updates        | 469677   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25352    |
# |    fps              | 168      |
# |    time_elapsed     | 11168    |
# |    total_timesteps  | 1884038  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24       |
# |    n_updates        | 469759   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.8     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25356    |
# |    fps              | 168      |
# |    time_elapsed     | 11170    |
# |    total_timesteps  | 1884487  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.8     |
# |    n_updates        | 469871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25360    |
# |    fps              | 168      |
# |    time_elapsed     | 11173    |
# |    total_timesteps  | 1884983  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.5     |
# |    n_updates        | 469995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.8     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25364    |
# |    fps              | 168      |
# |    time_elapsed     | 11176    |
# |    total_timesteps  | 1885451  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 25.2     |
# |    n_updates        | 470112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25368    |
# |    fps              | 168      |
# |    time_elapsed     | 11178    |
# |    total_timesteps  | 1885707  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.3     |
# |    n_updates        | 470176   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25372    |
# |    fps              | 168      |
# |    time_elapsed     | 11179    |
# |    total_timesteps  | 1885956  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.5     |
# |    n_updates        | 470238   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25376    |
# |    fps              | 168      |
# |    time_elapsed     | 11181    |
# |    total_timesteps  | 1886283  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 36.3     |
# |    n_updates        | 470320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25380    |
# |    fps              | 168      |
# |    time_elapsed     | 11183    |
# |    total_timesteps  | 1886564  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.8     |
# |    n_updates        | 470390   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25384    |
# |    fps              | 168      |
# |    time_elapsed     | 11184    |
# |    total_timesteps  | 1886856  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30       |
# |    n_updates        | 470463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25388    |
# |    fps              | 168      |
# |    time_elapsed     | 11189    |
# |    total_timesteps  | 1887588  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.5     |
# |    n_updates        | 470646   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25392    |
# |    fps              | 168      |
# |    time_elapsed     | 11191    |
# |    total_timesteps  | 1887925  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.4     |
# |    n_updates        | 470731   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25396    |
# |    fps              | 168      |
# |    time_elapsed     | 11194    |
# |    total_timesteps  | 1888475  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.1     |
# |    n_updates        | 470868   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25400    |
# |    fps              | 168      |
# |    time_elapsed     | 11197    |
# |    total_timesteps  | 1888927  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.6     |
# |    n_updates        | 470981   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.4     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25404    |
# |    fps              | 168      |
# |    time_elapsed     | 11199    |
# |    total_timesteps  | 1889339  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21.8     |
# |    n_updates        | 471084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25408    |
# |    fps              | 168      |
# |    time_elapsed     | 11203    |
# |    total_timesteps  | 1889930  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.6     |
# |    n_updates        | 471232   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25412    |
# |    fps              | 168      |
# |    time_elapsed     | 11205    |
# |    total_timesteps  | 1890260  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.6     |
# |    n_updates        | 471314   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25416    |
# |    fps              | 168      |
# |    time_elapsed     | 11208    |
# |    total_timesteps  | 1890715  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 69.5     |
# |    n_updates        | 471428   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25420    |
# |    fps              | 168      |
# |    time_elapsed     | 11211    |
# |    total_timesteps  | 1891302  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.2     |
# |    n_updates        | 471575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25424    |
# |    fps              | 168      |
# |    time_elapsed     | 11214    |
# |    total_timesteps  | 1891726  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.9     |
# |    n_updates        | 471681   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25428    |
# |    fps              | 168      |
# |    time_elapsed     | 11216    |
# |    total_timesteps  | 1892052  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.5     |
# |    n_updates        | 471762   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25432    |
# |    fps              | 168      |
# |    time_elapsed     | 11217    |
# |    total_timesteps  | 1892316  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.6     |
# |    n_updates        | 471828   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25436    |
# |    fps              | 168      |
# |    time_elapsed     | 11221    |
# |    total_timesteps  | 1892851  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.4     |
# |    n_updates        | 471962   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25440    |
# |    fps              | 168      |
# |    time_elapsed     | 11223    |
# |    total_timesteps  | 1893229  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.7     |
# |    n_updates        | 472057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25444    |
# |    fps              | 168      |
# |    time_elapsed     | 11226    |
# |    total_timesteps  | 1893715  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.2     |
# |    n_updates        | 472178   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25448    |
# |    fps              | 168      |
# |    time_elapsed     | 11228    |
# |    total_timesteps  | 1894037  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.1     |
# |    n_updates        | 472259   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25452    |
# |    fps              | 168      |
# |    time_elapsed     | 11230    |
# |    total_timesteps  | 1894466  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.3     |
# |    n_updates        | 472366   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25456    |
# |    fps              | 168      |
# |    time_elapsed     | 11233    |
# |    total_timesteps  | 1894849  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39       |
# |    n_updates        | 472462   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25460    |
# |    fps              | 168      |
# |    time_elapsed     | 11237    |
# |    total_timesteps  | 1895588  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 42.3     |
# |    n_updates        | 472646   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25464    |
# |    fps              | 168      |
# |    time_elapsed     | 11240    |
# |    total_timesteps  | 1896115  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.3     |
# |    n_updates        | 472778   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25468    |
# |    fps              | 168      |
# |    time_elapsed     | 11242    |
# |    total_timesteps  | 1896355  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.7     |
# |    n_updates        | 472838   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25472    |
# |    fps              | 168      |
# |    time_elapsed     | 11244    |
# |    total_timesteps  | 1896749  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 41.7     |
# |    n_updates        | 472937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25476    |
# |    fps              | 168      |
# |    time_elapsed     | 11246    |
# |    total_timesteps  | 1897112  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33.5     |
# |    n_updates        | 473027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25480    |
# |    fps              | 168      |
# |    time_elapsed     | 11248    |
# |    total_timesteps  | 1897452  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.7     |
# |    n_updates        | 473112   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25484    |
# |    fps              | 168      |
# |    time_elapsed     | 11250    |
# |    total_timesteps  | 1897808  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.7     |
# |    n_updates        | 473201   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25488    |
# |    fps              | 168      |
# |    time_elapsed     | 11254    |
# |    total_timesteps  | 1898319  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 56.9     |
# |    n_updates        | 473329   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25492    |
# |    fps              | 168      |
# |    time_elapsed     | 11255    |
# |    total_timesteps  | 1898629  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.7     |
# |    n_updates        | 473407   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25496    |
# |    fps              | 168      |
# |    time_elapsed     | 11258    |
# |    total_timesteps  | 1899039  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.3     |
# |    n_updates        | 473509   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25500    |
# |    fps              | 168      |
# |    time_elapsed     | 11260    |
# |    total_timesteps  | 1899344  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24       |
# |    n_updates        | 473585   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25504    |
# |    fps              | 168      |
# |    time_elapsed     | 11263    |
# |    total_timesteps  | 1899801  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 47.6     |
# |    n_updates        | 473700   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25508    |
# |    fps              | 168      |
# |    time_elapsed     | 11265    |
# |    total_timesteps  | 1900215  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.5     |
# |    n_updates        | 473803   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25512    |
# |    fps              | 168      |
# |    time_elapsed     | 11268    |
# |    total_timesteps  | 1900718  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 52.4     |
# |    n_updates        | 473929   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25516    |
# |    fps              | 168      |
# |    time_elapsed     | 11271    |
# |    total_timesteps  | 1901141  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.5     |
# |    n_updates        | 474035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 20.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25520    |
# |    fps              | 168      |
# |    time_elapsed     | 11272    |
# |    total_timesteps  | 1901381  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31.2     |
# |    n_updates        | 474095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25524    |
# |    fps              | 168      |
# |    time_elapsed     | 11274    |
# |    total_timesteps  | 1901670  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 53.4     |
# |    n_updates        | 474167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 25528    |
# |    fps              | 168      |
# |    time_elapsed     | 11276    |
# |    total_timesteps  | 1902010  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.6     |
# |    n_updates        | 474252   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.1      |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26384    |
# |    fps              | 168      |
# |    time_elapsed     | 11797    |
# |    total_timesteps  | 1988626  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 43.2     |
# |    n_updates        | 495906   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26388    |
# |    fps              | 168      |
# |    time_elapsed     | 11799    |
# |    total_timesteps  | 1989037  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.4     |
# |    n_updates        | 496009   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26392    |
# |    fps              | 168      |
# |    time_elapsed     | 11802    |
# |    total_timesteps  | 1989482  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 57.5     |
# |    n_updates        | 496120   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26396    |
# |    fps              | 168      |
# |    time_elapsed     | 11805    |
# |    total_timesteps  | 1989898  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 40.7     |
# |    n_updates        | 496224   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26400    |
# |    fps              | 168      |
# |    time_elapsed     | 11807    |
# |    total_timesteps  | 1990220  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 53.4     |
# |    n_updates        | 496304   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26404    |
# |    fps              | 168      |
# |    time_elapsed     | 11809    |
# |    total_timesteps  | 1990603  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 48.3     |
# |    n_updates        | 496400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26408    |
# |    fps              | 168      |
# |    time_elapsed     | 11812    |
# |    total_timesteps  | 1991171  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 70.4     |
# |    n_updates        | 496542   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.4     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26412    |
# |    fps              | 168      |
# |    time_elapsed     | 11815    |
# |    total_timesteps  | 1991575  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.2     |
# |    n_updates        | 496643   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26416    |
# |    fps              | 168      |
# |    time_elapsed     | 11820    |
# |    total_timesteps  | 1992430  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26       |
# |    n_updates        | 496857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26420    |
# |    fps              | 168      |
# |    time_elapsed     | 11822    |
# |    total_timesteps  | 1992801  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21       |
# |    n_updates        | 496950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26424    |
# |    fps              | 168      |
# |    time_elapsed     | 11824    |
# |    total_timesteps  | 1993103  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 48       |
# |    n_updates        | 497025   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26428    |
# |    fps              | 168      |
# |    time_elapsed     | 11827    |
# |    total_timesteps  | 1993602  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.2     |
# |    n_updates        | 497150   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26432    |
# |    fps              | 168      |
# |    time_elapsed     | 11828    |
# |    total_timesteps  | 1993846  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38       |
# |    n_updates        | 497211   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26436    |
# |    fps              | 168      |
# |    time_elapsed     | 11831    |
# |    total_timesteps  | 1994257  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.5     |
# |    n_updates        | 497314   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26440    |
# |    fps              | 168      |
# |    time_elapsed     | 11833    |
# |    total_timesteps  | 1994557  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 45.7     |
# |    n_updates        | 497389   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26444    |
# |    fps              | 168      |
# |    time_elapsed     | 11836    |
# |    total_timesteps  | 1995026  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 36.5     |
# |    n_updates        | 497506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26448    |
# |    fps              | 168      |
# |    time_elapsed     | 11838    |
# |    total_timesteps  | 1995401  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.7     |
# |    n_updates        | 497600   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26452    |
# |    fps              | 168      |
# |    time_elapsed     | 11840    |
# |    total_timesteps  | 1995772  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.6     |
# |    n_updates        | 497692   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26456    |
# |    fps              | 168      |
# |    time_elapsed     | 11842    |
# |    total_timesteps  | 1996053  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 32.6     |
# |    n_updates        | 497763   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 112      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26460    |
# |    fps              | 168      |
# |    time_elapsed     | 11843    |
# |    total_timesteps  | 1996297  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.2     |
# |    n_updates        | 497824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26464    |
# |    fps              | 168      |
# |    time_elapsed     | 11845    |
# |    total_timesteps  | 1996603  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.2     |
# |    n_updates        | 497900   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26468    |
# |    fps              | 168      |
# |    time_elapsed     | 11847    |
# |    total_timesteps  | 1996986  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.4     |
# |    n_updates        | 497996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26472    |
# |    fps              | 168      |
# |    time_elapsed     | 11849    |
# |    total_timesteps  | 1997226  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 49.2     |
# |    n_updates        | 498056   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 20.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26476    |
# |    fps              | 168      |
# |    time_elapsed     | 11852    |
# |    total_timesteps  | 1997733  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.5     |
# |    n_updates        | 498183   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26480    |
# |    fps              | 168      |
# |    time_elapsed     | 11853    |
# |    total_timesteps  | 1997978  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.2     |
# |    n_updates        | 498244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26484    |
# |    fps              | 168      |
# |    time_elapsed     | 11856    |
# |    total_timesteps  | 1998436  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 35.8     |
# |    n_updates        | 498358   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.6     |
# |    ep_rew_mean      | 19.6     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26488    |
# |    fps              | 168      |
# |    time_elapsed     | 11859    |
# |    total_timesteps  | 1998894  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 40       |
# |    n_updates        | 498473   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.1     |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26492    |
# |    fps              | 168      |
# |    time_elapsed     | 11861    |
# |    total_timesteps  | 1999189  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 46.5     |
# |    n_updates        | 498547   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26496    |
# |    fps              | 168      |
# |    time_elapsed     | 11863    |
# |    total_timesteps  | 1999519  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 48.8     |
# |    n_updates        | 498629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.6     |
# |    ep_rew_mean      | 18.9     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 26500    |
# |    fps              | 168      |
# |    time_elapsed     | 11864    |
# |    total_timesteps  | 1999782  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.4     |
# |    n_updates        | 498695   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Baseline: {'avg_pipes': np.float64(5.62), 'best': np.int64(22), 'avg_len': np.float64(298.74)}

# %% [markdown]
# ## 7 · Proposed – Inception CNN
# Repeats the same training budget with the Inception extractor and prints the
# same evaluation metrics for direct comparison.

# %%
inception  = train_agent(InceptionExtractor, "inception")gvy
metrics_i  = evaluate(inception)
print("Inception:", metrics_i)

# %% [markdown]
# ## 8 · Save Best Model
# Stores the trained Inception agent (`inception_qrdqn.zip`) for later reuse /
# demo without retraining.

# %%
inception.save("inception_qrdqn.zip")
print("Model written to inception_qrdqn.zip")
# Out:
# Model written to inception_qrdqn.zip

# %% [markdown]
# ## 9 · Reload & Final Metrics
# Reloads the saved ZIP, runs a fresh 50‑episode evaluation (no living bonus),
# and reports average pipes, best episode, and average survival frames.

# %%
from sb3_contrib import QRDQN
inception = QRDQN.load("inception_qrdqn.zip", device="cuda" if torch.cuda.is_available() else "cpu")
print("Inception agent loaded")

import numpy as np, gymnasium as gym

def evaluate(agent, episodes=50, gap=100):
    env = FlappyPixelEnv(gap=gap)
    scores, lengths = [], []
    for _ in range(episodes):
        obs, _ = env.reset()
        pipes = frames = 0
        done = False
        while not done:
            act, _ = agent.predict(obs, deterministic=True)
            obs, r, done, _, _ = env.step(act)
            if r > 0.9:
                pipes += 1
            frames += 1
        scores.append(pipes); lengths.append(frames)
    return {
        "avg_pipes": float(np.mean(scores)),
        "best":      int(np.max(scores)),
        "avg_len":   float(np.mean(lengths))
    }

metrics_inc = evaluate(inception)
print(f"Inception CNN – avg pipes: {metrics_inc['avg_pipes']:.2f}  |  "
      f"best: {metrics_inc['best']}  |  avg frames: {metrics_inc['avg_len']:.0f}")
# Out:
# Inception agent loaded
# Inception CNN – avg pipes: 13.18  |  best: 61  |  avg frames: 606

# %%
from sb3_contrib import QRDQN
model = QRDQN.load("inception_qrdqn.zip", device="cpu")

import imageio.v3 as iio, numpy as np
env = FlappyPixelEnv()
obs,_ = env.reset()
frames = []
done = False; pipes = 0
while not done:
    act,_ = model.predict(obs, deterministic=True)
    obs,r,done,_,_ = env.step(act)
    if r > 0.9: pipes += 1
    rgb = np.repeat(obs[-1][...,None], 3, axis=2)
    frames.append(rgb.astype(np.uint8))

print(f"Episode finished – pipes cleared: {pipes}")

iio.imwrite("play_demo.mp4", np.stack(frames), fps=15, codec="libx264")
from IPython.display import Video, display
display(Video("play_demo.mp4", embed=True))
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (84, 84) to (96, 96) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Episode finished – pipes cleared: 21
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
