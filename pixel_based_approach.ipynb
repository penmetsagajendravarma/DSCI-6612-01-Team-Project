# %%
# !pip install gymnasium==0.29.1 pygame stable-baselines3[extra] sb3-contrib --quiet

import gymnasium as gym, numpy as np, random, pygame, cv2, torch
from gymnasium import spaces
from sb3_contrib import QRDQN
from stable_baselines3.common.monitor import Monitor
from collections import deque

SCREEN_W, SCREEN_H = 288, 512
BASEY = int(SCREEN_H*0.79)
pygame.init()

def new_pipe():
    gap_y = random.randint(100, 300)
    x     = SCREEN_W + 10
    return [{'x': x, 'y': gap_y-320}, {'x': x, 'y': gap_y+100}]

class FlappyCore:
    """Pure game‑state (no Gym) so we can reuse for vector or pixel."""
    def __init__(self):
        self.reset()
    def reset(self):
        self.bird_y, self.vel_y = SCREEN_H//2, -9
        self.pipes = list(new_pipe())
        self.score = 0
    def step(self, action):
        if action and self.bird_y > -24: self.vel_y = -9
        self.vel_y = min(self.vel_y+1, 10)
        self.bird_y += self.vel_y
        for p in self.pipes: p['x'] -= 4
        if self.pipes[-1]['x'] < SCREEN_W-150: self.pipes.extend(new_pipe())
        if self.pipes[0]['x'] < -52: self.pipes = self.pipes[2:]

        up, lo = self.pipes[0], self.pipes[1]
        terminated = self.bird_y+24 >= BASEY or (
            up['x'] < 60 < up['x']+52 and
            not (up['y']+320 < self.bird_y < lo['y']-24))
        reward = -1.0 if terminated else 0.0
        if not terminated and up['x']+52 < 60 <= up['x']+56:
            reward = 1.0; self.score += 1
        return reward, terminated

class FlappyPixelEnv(gym.Env):
    metadata = {"render_modes": []}
    def __init__(self, frame_stack=4):
        self.game = FlappyCore()
        self.stack = deque(maxlen=frame_stack)
        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(
            0, 255, shape=(frame_stack, 84, 84), dtype=np.uint8)
        self.canvas = pygame.Surface((SCREEN_W, SCREEN_H))
    def _render_rgb(self):
        self.canvas.fill((135,206,250))
        for i in range(0, len(self.game.pipes), 2):
            up, lo = self.game.pipes[i], self.game.pipes[i+1]
            pygame.draw.rect(self.canvas, (0,255,0),
                             pygame.Rect(up['x'], up['y'], 52, 320))
            pygame.draw.rect(self.canvas, (0,255,0),
                             pygame.Rect(lo['x'], lo['y'], 52, 320))
        pygame.draw.rect(self.canvas, (255,255,0),
                         pygame.Rect(60, self.game.bird_y, 34, 24))
        arr = pygame.surfarray.array3d(self.canvas).swapaxes(0,1)  # HWC
        gray = cv2.cvtColor(arr, cv2.COLOR_RGB2GRAY)
        return cv2.resize(gray, (84,84), interpolation=cv2.INTER_AREA)
    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.game.reset()
        frame = self._render_rgb()
        self.stack.clear()
        for _ in range(self.stack.maxlen): self.stack.append(frame)
        obs = np.array(self.stack, dtype=np.uint8)
        return obs, {}
    def step(self, action):
        reward, terminated = self.game.step(int(action))
        frame = self._render_rgb()
        self.stack.append(frame)
        obs = np.array(self.stack, dtype=np.uint8)
        reward += 0.2
        return obs, reward, terminated, False, {}

env = Monitor(FlappyPixelEnv())
dqn_pix = QRDQN(
    "CnnPolicy",
    env,
    learning_rate      = 5e-4,
    buffer_size        = 50_000,
    learning_starts    = 5_000,
    batch_size         = 32,
    target_update_interval = 1_000,
    exploration_fraction  = 0.15,
    gamma              = 0.99,
    verbose            = 1,
)
dqn_pix.learn(total_timesteps=750_000, progress_bar=True)

def evaluate(agent, episodes=50):
    test_env = FlappyPixelEnv()
    scores=[]
    for _ in range(episodes):
        obs, _ = test_env.reset()
        done, pipes = False, 0
        while not done:
            act, _ = agent.predict(obs, deterministic=True)
            obs, r, done, _, _ = test_env.step(act)
            if r == 1.0: pipes += 1
        scores.append(pipes)
    return np.mean(scores), np.max(scores)

avg, best = evaluate(dqn_pix)
print(f"\nPixel agent  —  average pipes: {avg:.1f}   |   best: {best}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 98.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.1 which is incompatible.
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# Output()
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_output.py:111: DeprecationWarning:
# Kernel._parent_header is deprecated in ipykernel 6. Use .get_parent()
#   if ip and hasattr(ip, 'kernel') and hasattr(ip.kernel, '_parent_header'):
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.9     |
# |    n_updates        | 97894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.4     |
# |    ep_rew_mean      | 18.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6160     |
# |    fps              | 168      |
# |    time_elapsed     | 2351     |
# |    total_timesteps  | 396911   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.6     |
# |    n_updates        | 97977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6164     |
# |    fps              | 168      |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 397152   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.1     |
# |    n_updates        | 98037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.9     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6168     |
# |    fps              | 168      |
# |    time_elapsed     | 2355     |
# |    total_timesteps  | 397543   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.1     |
# |    n_updates        | 98135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.3     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6172     |
# |    fps              | 168      |
# |    time_elapsed     | 2359     |
# |    total_timesteps  | 398158   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.5     |
# |    n_updates        | 98289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6176     |
# |    fps              | 168      |
# |    time_elapsed     | 2361     |
# |    total_timesteps  | 398533   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11       |
# |    n_updates        | 98383    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.4     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6180     |
# |    fps              | 168      |
# |    time_elapsed     | 2363     |
# |    total_timesteps  | 398896   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.3     |
# |    n_updates        | 98473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6184     |
# |    fps              | 168      |
# |    time_elapsed     | 2367     |
# |    total_timesteps  | 399435   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.1     |
# |    n_updates        | 98608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.2     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6188     |
# |    fps              | 168      |
# |    time_elapsed     | 2370     |
# |    total_timesteps  | 399972   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.5     |
# |    n_updates        | 98742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6192     |
# |    fps              | 168      |
# |    time_elapsed     | 2373     |
# |    total_timesteps  | 400476   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.2      |
# |    n_updates        | 98868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6196     |
# |    fps              | 168      |
# |    time_elapsed     | 2375     |
# |    total_timesteps  | 400768   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 47.6     |
# |    n_updates        | 98941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | 19       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6200     |
# |    fps              | 168      |
# |    time_elapsed     | 2377     |
# |    total_timesteps  | 401227   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.9     |
# |    n_updates        | 99056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6204     |
# |    fps              | 168      |
# |    time_elapsed     | 2381     |
# |    total_timesteps  | 401896   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.9     |
# |    n_updates        | 99223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6208     |
# |    fps              | 168      |
# |    time_elapsed     | 2385     |
# |    total_timesteps  | 402478   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.3     |
# |    n_updates        | 99369    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6212     |
# |    fps              | 168      |
# |    time_elapsed     | 2391     |
# |    total_timesteps  | 403555   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.1     |
# |    n_updates        | 99638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6216     |
# |    fps              | 168      |
# |    time_elapsed     | 2395     |
# |    total_timesteps  | 404095   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.2     |
# |    n_updates        | 99773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6220     |
# |    fps              | 168      |
# |    time_elapsed     | 2397     |
# |    total_timesteps  | 404552   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21.3     |
# |    n_updates        | 99887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6224     |
# |    fps              | 168      |
# |    time_elapsed     | 2401     |
# |    total_timesteps  | 405089   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 31       |
# |    n_updates        | 100022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | 23.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6228     |
# |    fps              | 168      |
# |    time_elapsed     | 2404     |
# |    total_timesteps  | 405635   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.3     |
# |    n_updates        | 100158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | 24.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6232     |
# |    fps              | 168      |
# |    time_elapsed     | 2408     |
# |    total_timesteps  | 406265   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.4     |
# |    n_updates        | 100316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6236     |
# |    fps              | 168      |
# |    time_elapsed     | 2413     |
# |    total_timesteps  | 407085   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.2     |
# |    n_updates        | 100521   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | 26.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6240     |
# |    fps              | 168      |
# |    time_elapsed     | 2416     |
# |    total_timesteps  | 407666   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.4     |
# |    n_updates        | 100666   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 27.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6244     |
# |    fps              | 168      |
# |    time_elapsed     | 2422     |
# |    total_timesteps  | 408629   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.4     |
# |    n_updates        | 100907   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6248     |
# |    fps              | 168      |
# |    time_elapsed     | 2425     |
# |    total_timesteps  | 409208   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18       |
# |    n_updates        | 101051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6252     |
# |    fps              | 168      |
# |    time_elapsed     | 2428     |
# |    total_timesteps  | 409662   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.7     |
# |    n_updates        | 101165   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 27.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6256     |
# |    fps              | 168      |
# |    time_elapsed     | 2431     |
# |    total_timesteps  | 410107   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.4     |
# |    n_updates        | 101276   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6260     |
# |    fps              | 168      |
# |    time_elapsed     | 2434     |
# |    total_timesteps  | 410574   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.7     |
# |    n_updates        | 101393   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 28.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6264     |
# |    fps              | 168      |
# |    time_elapsed     | 2436     |
# |    total_timesteps  | 410920   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.3     |
# |    n_updates        | 101479   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6268     |
# |    fps              | 168      |
# |    time_elapsed     | 2441     |
# |    total_timesteps  | 411698   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.6     |
# |    n_updates        | 101674   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6272     |
# |    fps              | 168      |
# |    time_elapsed     | 2443     |
# |    total_timesteps  | 412156   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.3     |
# |    n_updates        | 101788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6276     |
# |    fps              | 168      |
# |    time_elapsed     | 2448     |
# |    total_timesteps  | 412873   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.8     |
# |    n_updates        | 101968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6280     |
# |    fps              | 168      |
# |    time_elapsed     | 2453     |
# |    total_timesteps  | 413665   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.6     |
# |    n_updates        | 102166   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6284     |
# |    fps              | 168      |
# |    time_elapsed     | 2455     |
# |    total_timesteps  | 414090   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.6     |
# |    n_updates        | 102272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6288     |
# |    fps              | 168      |
# |    time_elapsed     | 2457     |
# |    total_timesteps  | 414383   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.2     |
# |    n_updates        | 102345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6292     |
# |    fps              | 168      |
# |    time_elapsed     | 2459     |
# |    total_timesteps  | 414681   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.7     |
# |    n_updates        | 102420   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6296     |
# |    fps              | 168      |
# |    time_elapsed     | 2464     |
# |    total_timesteps  | 415552   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.4     |
# |    n_updates        | 102637   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 31       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6300     |
# |    fps              | 168      |
# |    time_elapsed     | 2468     |
# |    total_timesteps  | 416180   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.2     |
# |    n_updates        | 102794   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6304     |
# |    fps              | 168      |
# |    time_elapsed     | 2476     |
# |    total_timesteps  | 417474   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.5     |
# |    n_updates        | 103118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6308     |
# |    fps              | 168      |
# |    time_elapsed     | 2478     |
# |    total_timesteps  | 417881   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 32       |
# |    n_updates        | 103220   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6312     |
# |    fps              | 168      |
# |    time_elapsed     | 2484     |
# |    total_timesteps  | 418912   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 52.6     |
# |    n_updates        | 103477   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6316     |
# |    fps              | 168      |
# |    time_elapsed     | 2488     |
# |    total_timesteps  | 419448   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.7     |
# |    n_updates        | 103611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 32.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6320     |
# |    fps              | 168      |
# |    time_elapsed     | 2491     |
# |    total_timesteps  | 420064   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21.9     |
# |    n_updates        | 103765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 32       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6324     |
# |    fps              | 168      |
# |    time_elapsed     | 2494     |
# |    total_timesteps  | 420477   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.3     |
# |    n_updates        | 103869   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 32.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6328     |
# |    fps              | 168      |
# |    time_elapsed     | 2498     |
# |    total_timesteps  | 421110   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.8     |
# |    n_updates        | 104027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6332     |
# |    fps              | 168      |
# |    time_elapsed     | 2500     |
# |    total_timesteps  | 421399   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22       |
# |    n_updates        | 104099   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 30.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6336     |
# |    fps              | 168      |
# |    time_elapsed     | 2502     |
# |    total_timesteps  | 421862   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.1     |
# |    n_updates        | 104215   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 30.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6340     |
# |    fps              | 168      |
# |    time_elapsed     | 2505     |
# |    total_timesteps  | 422339   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.7     |
# |    n_updates        | 104334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 29.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6344     |
# |    fps              | 168      |
# |    time_elapsed     | 2509     |
# |    total_timesteps  | 422960   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.7     |
# |    n_updates        | 104489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 29.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6348     |
# |    fps              | 168      |
# |    time_elapsed     | 2513     |
# |    total_timesteps  | 423617   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.6     |
# |    n_updates        | 104654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | 30.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6352     |
# |    fps              | 168      |
# |    time_elapsed     | 2517     |
# |    total_timesteps  | 424280   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21.3     |
# |    n_updates        | 104819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 30.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6356     |
# |    fps              | 168      |
# |    time_elapsed     | 2521     |
# |    total_timesteps  | 424938   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.7     |
# |    n_updates        | 104984   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 31.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6360     |
# |    fps              | 168      |
# |    time_elapsed     | 2526     |
# |    total_timesteps  | 425688   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30.2     |
# |    n_updates        | 105171   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 31.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6364     |
# |    fps              | 168      |
# |    time_elapsed     | 2527     |
# |    total_timesteps  | 425948   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.3     |
# |    n_updates        | 105236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 30.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6368     |
# |    fps              | 168      |
# |    time_elapsed     | 2530     |
# |    total_timesteps  | 426442   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 25.4     |
# |    n_updates        | 105360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 31.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6372     |
# |    fps              | 168      |
# |    time_elapsed     | 2536     |
# |    total_timesteps  | 427379   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.8     |
# |    n_updates        | 105594   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 33.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6376     |
# |    fps              | 168      |
# |    time_elapsed     | 2545     |
# |    total_timesteps  | 428951   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.1     |
# |    n_updates        | 105987   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6380     |
# |    fps              | 168      |
# |    time_elapsed     | 2547     |
# |    total_timesteps  | 429264   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21       |
# |    n_updates        | 106065   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 33.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6384     |
# |    fps              | 168      |
# |    time_elapsed     | 2552     |
# |    total_timesteps  | 430024   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.8     |
# |    n_updates        | 106255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 33.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6388     |
# |    fps              | 168      |
# |    time_elapsed     | 2555     |
# |    total_timesteps  | 430447   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.3     |
# |    n_updates        | 106361   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6392     |
# |    fps              | 168      |
# |    time_elapsed     | 2557     |
# |    total_timesteps  | 430823   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.1     |
# |    n_updates        | 106455   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6396     |
# |    fps              | 168      |
# |    time_elapsed     | 2560     |
# |    total_timesteps  | 431257   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 40.2     |
# |    n_updates        | 106564   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 33.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6400     |
# |    fps              | 168      |
# |    time_elapsed     | 2564     |
# |    total_timesteps  | 432071   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.7     |
# |    n_updates        | 106767   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6404     |
# |    fps              | 168      |
# |    time_elapsed     | 2569     |
# |    total_timesteps  | 432821   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 43.8     |
# |    n_updates        | 106955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 32.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6408     |
# |    fps              | 168      |
# |    time_elapsed     | 2573     |
# |    total_timesteps  | 433482   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.1     |
# |    n_updates        | 107120   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 31.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6412     |
# |    fps              | 168      |
# |    time_elapsed     | 2578     |
# |    total_timesteps  | 434272   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.3     |
# |    n_updates        | 107317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 32.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6416     |
# |    fps              | 168      |
# |    time_elapsed     | 2583     |
# |    total_timesteps  | 435175   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.2     |
# |    n_updates        | 107543   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 33.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6420     |
# |    fps              | 168      |
# |    time_elapsed     | 2589     |
# |    total_timesteps  | 436156   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.4     |
# |    n_updates        | 107788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6424     |
# |    fps              | 168      |
# |    time_elapsed     | 2592     |
# |    total_timesteps  | 436654   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.8     |
# |    n_updates        | 107913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | 35.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6428     |
# |    fps              | 168      |
# |    time_elapsed     | 2600     |
# |    total_timesteps  | 437921   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.7     |
# |    n_updates        | 108230   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6432     |
# |    fps              | 168      |
# |    time_elapsed     | 2603     |
# |    total_timesteps  | 438456   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 45.6     |
# |    n_updates        | 108363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 37.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6436     |
# |    fps              | 168      |
# |    time_elapsed     | 2611     |
# |    total_timesteps  | 439701   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28       |
# |    n_updates        | 108675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 38.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6440     |
# |    fps              | 168      |
# |    time_elapsed     | 2617     |
# |    total_timesteps  | 440783   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.1     |
# |    n_updates        | 108945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 38.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6444     |
# |    fps              | 168      |
# |    time_elapsed     | 2621     |
# |    total_timesteps  | 441393   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.8     |
# |    n_updates        | 109098   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 38.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6448     |
# |    fps              | 168      |
# |    time_elapsed     | 2625     |
# |    total_timesteps  | 441988   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.5     |
# |    n_updates        | 109246   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 39.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6452     |
# |    fps              | 168      |
# |    time_elapsed     | 2632     |
# |    total_timesteps  | 443070   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.4     |
# |    n_updates        | 109517   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 40.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6456     |
# |    fps              | 168      |
# |    time_elapsed     | 2639     |
# |    total_timesteps  | 444268   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.8     |
# |    n_updates        | 109816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 40.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6460     |
# |    fps              | 168      |
# |    time_elapsed     | 2643     |
# |    total_timesteps  | 444887   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 46.4     |
# |    n_updates        | 109971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 42.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6464     |
# |    fps              | 168      |
# |    time_elapsed     | 2650     |
# |    total_timesteps  | 446145   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 25.1     |
# |    n_updates        | 110286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6468     |
# |    fps              | 168      |
# |    time_elapsed     | 2656     |
# |    total_timesteps  | 447123   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.4     |
# |    n_updates        | 110530   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 42.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6472     |
# |    fps              | 168      |
# |    time_elapsed     | 2659     |
# |    total_timesteps  | 447538   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.3     |
# |    n_updates        | 110634   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6476     |
# |    fps              | 168      |
# |    time_elapsed     | 2667     |
# |    total_timesteps  | 448868   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.6     |
# |    n_updates        | 110966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 43.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6480     |
# |    fps              | 168      |
# |    time_elapsed     | 2671     |
# |    total_timesteps  | 449646   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33.7     |
# |    n_updates        | 111161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 42.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6484     |
# |    fps              | 168      |
# |    time_elapsed     | 2674     |
# |    total_timesteps  | 450144   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.8     |
# |    n_updates        | 111285   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6488     |
# |    fps              | 168      |
# |    time_elapsed     | 2677     |
# |    total_timesteps  | 450534   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.4     |
# |    n_updates        | 111383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 43       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6492     |
# |    fps              | 168      |
# |    time_elapsed     | 2680     |
# |    total_timesteps  | 451125   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.4     |
# |    n_updates        | 111531   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 43.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6496     |
# |    fps              | 168      |
# |    time_elapsed     | 2684     |
# |    total_timesteps  | 451711   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 24.4     |
# |    n_updates        | 111677   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 42.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6500     |
# |    fps              | 168      |
# |    time_elapsed     | 2687     |
# |    total_timesteps  | 452129   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 23.1     |
# |    n_updates        | 111782   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 42.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6504     |
# |    fps              | 168      |
# |    time_elapsed     | 2690     |
# |    total_timesteps  | 452708   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.9     |
# |    n_updates        | 111926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 42.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 6508     |
# |    fps              | 168      |
# |    time_elapsed     | 2694     |
# |    total_timesteps  | 453399   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.6     |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 473      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7372     |
# |    fps              | 167      |
# |    time_elapsed     | 4228     |
# |    total_timesteps  | 706541   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.4     |
# |    n_updates        | 175385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7376     |
# |    fps              | 167      |
# |    time_elapsed     | 4240     |
# |    total_timesteps  | 708470   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.43     |
# |    n_updates        | 175867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 469      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7380     |
# |    fps              | 167      |
# |    time_elapsed     | 4246     |
# |    total_timesteps  | 709542   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.2     |
# |    n_updates        | 176135   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7384     |
# |    fps              | 167      |
# |    time_elapsed     | 4251     |
# |    total_timesteps  | 710326   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.8     |
# |    n_updates        | 176331   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 451      |
# |    ep_rew_mean      | 98.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7388     |
# |    fps              | 167      |
# |    time_elapsed     | 4260     |
# |    total_timesteps  | 711817   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.9     |
# |    n_updates        | 176704   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 447      |
# |    ep_rew_mean      | 97.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7392     |
# |    fps              | 167      |
# |    time_elapsed     | 4275     |
# |    total_timesteps  | 714300   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.2     |
# |    n_updates        | 177324   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 445      |
# |    ep_rew_mean      | 97.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7396     |
# |    fps              | 167      |
# |    time_elapsed     | 4280     |
# |    total_timesteps  | 715135   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.4     |
# |    n_updates        | 177533   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 433      |
# |    ep_rew_mean      | 94.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7400     |
# |    fps              | 167      |
# |    time_elapsed     | 4286     |
# |    total_timesteps  | 716229   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.7     |
# |    n_updates        | 177807   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 96.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7404     |
# |    fps              | 167      |
# |    time_elapsed     | 4301     |
# |    total_timesteps  | 718601   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.2     |
# |    n_updates        | 178400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 94.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7408     |
# |    fps              | 167      |
# |    time_elapsed     | 4304     |
# |    total_timesteps  | 719054   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.6     |
# |    n_updates        | 178513   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 426      |
# |    ep_rew_mean      | 93.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7412     |
# |    fps              | 167      |
# |    time_elapsed     | 4311     |
# |    total_timesteps  | 720247   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.9     |
# |    n_updates        | 178811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7416     |
# |    fps              | 167      |
# |    time_elapsed     | 4328     |
# |    total_timesteps  | 723063   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.1     |
# |    n_updates        | 179515   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 90.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7420     |
# |    fps              | 167      |
# |    time_elapsed     | 4331     |
# |    total_timesteps  | 723549   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.6     |
# |    n_updates        | 179637   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 406      |
# |    ep_rew_mean      | 88.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7424     |
# |    fps              | 167      |
# |    time_elapsed     | 4336     |
# |    total_timesteps  | 724385   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.4     |
# |    n_updates        | 179846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 89.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7428     |
# |    fps              | 167      |
# |    time_elapsed     | 4355     |
# |    total_timesteps  | 727503   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.5     |
# |    n_updates        | 180625   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 405      |
# |    ep_rew_mean      | 88.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7432     |
# |    fps              | 167      |
# |    time_elapsed     | 4360     |
# |    total_timesteps  | 728322   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.1     |
# |    n_updates        | 180830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 403      |
# |    ep_rew_mean      | 87.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7436     |
# |    fps              | 167      |
# |    time_elapsed     | 4366     |
# |    total_timesteps  | 729270   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.5     |
# |    n_updates        | 181067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 397      |
# |    ep_rew_mean      | 86.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7440     |
# |    fps              | 167      |
# |    time_elapsed     | 4371     |
# |    total_timesteps  | 730146   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18       |
# |    n_updates        | 181286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 403      |
# |    ep_rew_mean      | 87.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7444     |
# |    fps              | 167      |
# |    time_elapsed     | 4379     |
# |    total_timesteps  | 731452   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.4     |
# |    n_updates        | 181612   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 398      |
# |    ep_rew_mean      | 86.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7448     |
# |    fps              | 167      |
# |    time_elapsed     | 4382     |
# |    total_timesteps  | 731995   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.9     |
# |    n_updates        | 181748   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 380      |
# |    ep_rew_mean      | 82.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7452     |
# |    fps              | 167      |
# |    time_elapsed     | 4386     |
# |    total_timesteps  | 732657   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.1     |
# |    n_updates        | 181914   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 356      |
# |    ep_rew_mean      | 77.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7456     |
# |    fps              | 167      |
# |    time_elapsed     | 4392     |
# |    total_timesteps  | 733717   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 26.6     |
# |    n_updates        | 182179   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | 76.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7460     |
# |    fps              | 167      |
# |    time_elapsed     | 4402     |
# |    total_timesteps  | 735313   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.8     |
# |    n_updates        | 182578   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 338      |
# |    ep_rew_mean      | 73.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7464     |
# |    fps              | 167      |
# |    time_elapsed     | 4409     |
# |    total_timesteps  | 736510   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.5     |
# |    n_updates        | 182877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 361      |
# |    ep_rew_mean      | 78.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7468     |
# |    fps              | 167      |
# |    time_elapsed     | 4433     |
# |    total_timesteps  | 740415   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.7     |
# |    n_updates        | 183853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | 76.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7472     |
# |    fps              | 167      |
# |    time_elapsed     | 4440     |
# |    total_timesteps  | 741629   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 28.8     |
# |    n_updates        | 184157   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 354      |
# |    ep_rew_mean      | 76.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7476     |
# |    fps              | 167      |
# |    time_elapsed     | 4453     |
# |    total_timesteps  | 743884   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.2     |
# |    n_updates        | 184720   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | 79.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7480     |
# |    fps              | 167      |
# |    time_elapsed     | 4467     |
# |    total_timesteps  | 746030   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.1     |
# |    n_updates        | 185257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 370      |
# |    ep_rew_mean      | 80.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7484     |
# |    fps              | 167      |
# |    time_elapsed     | 4474     |
# |    total_timesteps  | 747313   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.8     |
# |    n_updates        | 185578   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 367      |
# |    ep_rew_mean      | 79.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7488     |
# |    fps              | 167      |
# |    time_elapsed     | 4482     |
# |    total_timesteps  | 748560   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.9     |
# |    n_updates        | 185889   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Pixel agent  —  average pipes: 0.0   |   best: 0

# %%
def patched_step(self, action):
    if action and self.bird_y > -24:
        self.vel_y = -9
    self.vel_y = min(self.vel_y + 1, 10)
    self.bird_y += self.vel_y

    prev_right = self.pipes[0]['x'] + 52
    for p in self.pipes: p['x'] -= 4
    if self.pipes[-1]['x'] < SCREEN_W-150:
        self.pipes.extend(new_pipe())
    if self.pipes[0]['x'] < -52:
        self.pipes = self.pipes[2:]
    curr_right = self.pipes[0]['x'] + 52

    up, lo = self.pipes[0], self.pipes[1]
    terminated = self.bird_y+24 >= BASEY or (
        up['x'] < 60 < up['x']+52 and
        not (up['y']+320 < self.bird_y < lo['y']-24))
    reward = -1.0 if terminated else 0.0
    if not terminated and prev_right >= 60 > curr_right:
        reward = 1.0
        self.score += 1
    return reward, terminated

FlappyCore.step = patched_step

dqn_pix.learn(total_timesteps=500_000, reset_num_timesteps=False, progress_bar=True)

avg, best = evaluate(dqn_pix)
print(f"\nPixel agent — average pipes: {avg:.1f}   |   best episode: {best}")
# Out:
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 363      |
# |    ep_rew_mean      | 78.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7492     |
# |    fps              | 157      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 750580   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.3     |
# |    n_updates        | 186394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 378      |
# |    ep_rew_mean      | 82.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7496     |
# |    fps              | 163      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 752953   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.5     |
# |    n_updates        | 186988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 384      |
# |    ep_rew_mean      | 83.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7500     |
# |    fps              | 163      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 754634   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.26     |
# |    n_updates        | 187408   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 379      |
# |    ep_rew_mean      | 82.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7504     |
# |    fps              | 163      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 756525   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.86     |
# |    n_updates        | 187881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 401      |
# |    ep_rew_mean      | 87.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7508     |
# |    fps              | 163      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 759149   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.7     |
# |    n_updates        | 188537   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 89.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7512     |
# |    fps              | 163      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 761425   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.3     |
# |    n_updates        | 189106   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 394      |
# |    ep_rew_mean      | 85.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7516     |
# |    fps              | 163      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 762469   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.69     |
# |    n_updates        | 189367   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | 90.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7520     |
# |    fps              | 164      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 765013   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.1     |
# |    n_updates        | 190003   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 435      |
# |    ep_rew_mean      | 95.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7524     |
# |    fps              | 164      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 767886   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.8     |
# |    n_updates        | 190721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | 90.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7528     |
# |    fps              | 164      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 769113   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20       |
# |    n_updates        | 191028   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | 92.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7532     |
# |    fps              | 164      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 770640   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.1     |
# |    n_updates        | 191409   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 429      |
# |    ep_rew_mean      | 93.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7536     |
# |    fps              | 164      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 772122   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.1     |
# |    n_updates        | 191780   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 437      |
# |    ep_rew_mean      | 95.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7540     |
# |    fps              | 164      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 773818   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17       |
# |    n_updates        | 192204   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 432      |
# |    ep_rew_mean      | 94.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7544     |
# |    fps              | 164      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 774701   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.9     |
# |    n_updates        | 192425   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 443      |
# |    ep_rew_mean      | 96.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7548     |
# |    fps              | 164      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 776327   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.4     |
# |    n_updates        | 192831   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7552     |
# |    fps              | 164      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 778610   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12       |
# |    n_updates        | 193402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7556     |
# |    fps              | 164      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 780171   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.5     |
# |    n_updates        | 193792   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 481      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7560     |
# |    fps              | 164      |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 783375   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.1     |
# |    n_updates        | 194593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 484      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7564     |
# |    fps              | 164      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 784934   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13       |
# |    n_updates        | 194983   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7568     |
# |    fps              | 164      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 787057   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.1     |
# |    n_updates        | 195514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7572     |
# |    fps              | 164      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 788162   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.45     |
# |    n_updates        | 195790   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 454      |
# |    ep_rew_mean      | 99.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7576     |
# |    fps              | 164      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 789274   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 30       |
# |    n_updates        | 196068   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 439      |
# |    ep_rew_mean      | 96       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7580     |
# |    fps              | 164      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 789927   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.92     |
# |    n_updates        | 196231   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 453      |
# |    ep_rew_mean      | 99.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7584     |
# |    fps              | 164      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 792645   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.2     |
# |    n_updates        | 196911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7588     |
# |    fps              | 164      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 794927   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.99     |
# |    n_updates        | 197481   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7592     |
# |    fps              | 164      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 796456   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 55.2     |
# |    n_updates        | 197863   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 98.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7596     |
# |    fps              | 164      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 797908   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.73     |
# |    n_updates        | 198226   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7600     |
# |    fps              | 164      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 800509   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.42     |
# |    n_updates        | 198877   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7604     |
# |    fps              | 164      |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 802848   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.53     |
# |    n_updates        | 199461   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7608     |
# |    fps              | 164      |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 805099   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.45     |
# |    n_updates        | 200024   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 452      |
# |    ep_rew_mean      | 98.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7612     |
# |    fps              | 164      |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 806579   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.2     |
# |    n_updates        | 200394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7616     |
# |    fps              | 164      |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 808519   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.23     |
# |    n_updates        | 200879   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 499      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7620     |
# |    fps              | 164      |
# |    time_elapsed     | 395      |
# |    total_timesteps  | 814960   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.3     |
# |    n_updates        | 202489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7624     |
# |    fps              | 164      |
# |    time_elapsed     | 400      |
# |    total_timesteps  | 815704   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.81     |
# |    n_updates        | 202675   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 491      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7628     |
# |    fps              | 164      |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 818201   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.7     |
# |    n_updates        | 203300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7632     |
# |    fps              | 164      |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 819519   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.47     |
# |    n_updates        | 203629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7636     |
# |    fps              | 164      |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 822392   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.2     |
# |    n_updates        | 204347   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7640     |
# |    fps              | 164      |
# |    time_elapsed     | 449      |
# |    total_timesteps  | 823788   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 10.4     |
# |    n_updates        | 204696   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7644     |
# |    fps              | 164      |
# |    time_elapsed     | 457      |
# |    total_timesteps  | 825153   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.48     |
# |    n_updates        | 205038   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7648     |
# |    fps              | 164      |
# |    time_elapsed     | 467      |
# |    total_timesteps  | 826809   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.98     |
# |    n_updates        | 205452   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7652     |
# |    fps              | 164      |
# |    time_elapsed     | 479      |
# |    total_timesteps  | 828862   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 43.1     |
# |    n_updates        | 205965   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 503      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7656     |
# |    fps              | 164      |
# |    time_elapsed     | 489      |
# |    total_timesteps  | 830520   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.55     |
# |    n_updates        | 206379   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 482      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7660     |
# |    fps              | 164      |
# |    time_elapsed     | 496      |
# |    total_timesteps  | 831594   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.91     |
# |    n_updates        | 206648   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7664     |
# |    fps              | 164      |
# |    time_elapsed     | 515      |
# |    total_timesteps  | 834751   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.3     |
# |    n_updates        | 207437   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 498      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7668     |
# |    fps              | 164      |
# |    time_elapsed     | 528      |
# |    total_timesteps  | 836846   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.6     |
# |    n_updates        | 207961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 516      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7672     |
# |    fps              | 164      |
# |    time_elapsed     | 546      |
# |    total_timesteps  | 839788   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.73     |
# |    n_updates        | 208696   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 521      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7676     |
# |    fps              | 164      |
# |    time_elapsed     | 555      |
# |    total_timesteps  | 841408   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.85     |
# |    n_updates        | 209101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 536      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7680     |
# |    fps              | 164      |
# |    time_elapsed     | 568      |
# |    total_timesteps  | 843520   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.49     |
# |    n_updates        | 209629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 530      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7684     |
# |    fps              | 164      |
# |    time_elapsed     | 581      |
# |    total_timesteps  | 845670   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 16.5     |
# |    n_updates        | 210167   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7688     |
# |    fps              | 164      |
# |    time_elapsed     | 592      |
# |    total_timesteps  | 847398   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.64     |
# |    n_updates        | 210599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7692     |
# |    fps              | 164      |
# |    time_elapsed     | 605      |
# |    total_timesteps  | 849537   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.84     |
# |    n_updates        | 211134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7696     |
# |    fps              | 164      |
# |    time_elapsed     | 623      |
# |    total_timesteps  | 852483   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.69     |
# |    n_updates        | 211870   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 533      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7700     |
# |    fps              | 164      |
# |    time_elapsed     | 631      |
# |    total_timesteps  | 853808   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.76     |
# |    n_updates        | 212201   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7704     |
# |    fps              | 164      |
# |    time_elapsed     | 641      |
# |    total_timesteps  | 855527   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.95     |
# |    n_updates        | 212631   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 537      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7708     |
# |    fps              | 164      |
# |    time_elapsed     | 661      |
# |    total_timesteps  | 858815   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.39     |
# |    n_updates        | 213453   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 542      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7712     |
# |    fps              | 164      |
# |    time_elapsed     | 673      |
# |    total_timesteps  | 860824   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.46     |
# |    n_updates        | 213955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 568      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7716     |
# |    fps              | 164      |
# |    time_elapsed     | 701      |
# |    total_timesteps  | 865344   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.34     |
# |    n_updates        | 215085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 511      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7720     |
# |    fps              | 164      |
# |    time_elapsed     | 705      |
# |    total_timesteps  | 866098   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.6     |
# |    n_updates        | 215274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 518      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7724     |
# |    fps              | 164      |
# |    time_elapsed     | 714      |
# |    total_timesteps  | 867540   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 20.9     |
# |    n_updates        | 215634   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 507      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7728     |
# |    fps              | 164      |
# |    time_elapsed     | 723      |
# |    total_timesteps  | 868944   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.27     |
# |    n_updates        | 215985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 507      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7732     |
# |    fps              | 164      |
# |    time_elapsed     | 730      |
# |    total_timesteps  | 870221   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.18     |
# |    n_updates        | 216305   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 491      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7736     |
# |    fps              | 164      |
# |    time_elapsed     | 738      |
# |    total_timesteps  | 871455   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 33.5     |
# |    n_updates        | 216613   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 485      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7740     |
# |    fps              | 164      |
# |    time_elapsed     | 743      |
# |    total_timesteps  | 872321   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.48     |
# |    n_updates        | 216830   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7744     |
# |    fps              | 164      |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 875685   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.78     |
# |    n_updates        | 217671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 507      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7748     |
# |    fps              | 164      |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 877486   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.44     |
# |    n_updates        | 218121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 520      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7752     |
# |    fps              | 164      |
# |    time_elapsed     | 795      |
# |    total_timesteps  | 880812   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.5     |
# |    n_updates        | 218952   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 522      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7756     |
# |    fps              | 164      |
# |    time_elapsed     | 807      |
# |    total_timesteps  | 882706   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.9     |
# |    n_updates        | 219426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 524      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7760     |
# |    fps              | 164      |
# |    time_elapsed     | 815      |
# |    total_timesteps  | 883971   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13       |
# |    n_updates        | 219742   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 506      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7764     |
# |    fps              | 164      |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 885401   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.85     |
# |    n_updates        | 220100   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 511      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7768     |
# |    fps              | 164      |
# |    time_elapsed     | 839      |
# |    total_timesteps  | 887991   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12       |
# |    n_updates        | 220747   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 505      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7772     |
# |    fps              | 164      |
# |    time_elapsed     | 853      |
# |    total_timesteps  | 890334   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19.5     |
# |    n_updates        | 221333   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7776     |
# |    fps              | 164      |
# |    time_elapsed     | 857      |
# |    total_timesteps  | 890960   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.7      |
# |    n_updates        | 221489   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 488      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7780     |
# |    fps              | 164      |
# |    time_elapsed     | 866      |
# |    total_timesteps  | 892357   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.63     |
# |    n_updates        | 221839   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 480      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7784     |
# |    fps              | 164      |
# |    time_elapsed     | 874      |
# |    total_timesteps  | 893633   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.9     |
# |    n_updates        | 222158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 477      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7788     |
# |    fps              | 164      |
# |    time_elapsed     | 882      |
# |    total_timesteps  | 895049   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 14.3     |
# |    n_updates        | 222512   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 479      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7792     |
# |    fps              | 164      |
# |    time_elapsed     | 897      |
# |    total_timesteps  | 897399   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 13.7     |
# |    n_updates        | 223099   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 458      |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7796     |
# |    fps              | 164      |
# |    time_elapsed     | 902      |
# |    total_timesteps  | 898241   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.02     |
# |    n_updates        | 223310   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7800     |
# |    fps              | 164      |
# |    time_elapsed     | 912      |
# |    total_timesteps  | 899891   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 15.6     |
# |    n_updates        | 223722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7804     |
# |    fps              | 164      |
# |    time_elapsed     | 924      |
# |    total_timesteps  | 901801   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.2     |
# |    n_updates        | 224200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7808     |
# |    fps              | 164      |
# |    time_elapsed     | 942      |
# |    total_timesteps  | 904878   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 18.7     |
# |    n_updates        | 224969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7812     |
# |    fps              | 164      |
# |    time_elapsed     | 954      |
# |    total_timesteps  | 906840   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.19     |
# |    n_updates        | 225459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 96.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7816     |
# |    fps              | 164      |
# |    time_elapsed     | 970      |
# |    total_timesteps  | 909420   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.44     |
# |    n_updates        | 226104   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 456      |
# |    ep_rew_mean      | 99.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7820     |
# |    fps              | 164      |
# |    time_elapsed     | 984      |
# |    total_timesteps  | 911681   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 38.6     |
# |    n_updates        | 226670   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 455      |
# |    ep_rew_mean      | 99.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7824     |
# |    fps              | 164      |
# |    time_elapsed     | 992      |
# |    total_timesteps  | 913060   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.48     |
# |    n_updates        | 227014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7828     |
# |    fps              | 164      |
# |    time_elapsed     | 1009     |
# |    total_timesteps  | 915724   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 65.8     |
# |    n_updates        | 227680   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 472      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7832     |
# |    fps              | 164      |
# |    time_elapsed     | 1019     |
# |    total_timesteps  | 917447   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.4     |
# |    n_updates        | 228111   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7836     |
# |    fps              | 164      |
# |    time_elapsed     | 1025     |
# |    total_timesteps  | 918456   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.59     |
# |    n_updates        | 228363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 478      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7840     |
# |    fps              | 164      |
# |    time_elapsed     | 1036     |
# |    total_timesteps  | 920124   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 12.4     |
# |    n_updates        | 228780   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 459      |
# |    ep_rew_mean      | 100      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7844     |
# |    fps              | 164      |
# |    time_elapsed     | 1044     |
# |    total_timesteps  | 921540   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 11.7     |
# |    n_updates        | 229134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7848     |
# |    fps              | 164      |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 924864   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 22.1     |
# |    n_updates        | 229965   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 102      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 7852     |
# |    fps              | 164      |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 927260   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 17.7     |
# |    n_updates        | 230564   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 101      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 617      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8332     |
# |    fps              | 163      |
# |    time_elapsed     | 2555     |
# |    total_timesteps  | 1167890  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.78     |
# |    n_updates        | 290722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 633      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8336     |
# |    fps              | 163      |
# |    time_elapsed     | 2570     |
# |    total_timesteps  | 1170367  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 27.2     |
# |    n_updates        | 291341   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 646      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8340     |
# |    fps              | 163      |
# |    time_elapsed     | 2595     |
# |    total_timesteps  | 1174430  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.27     |
# |    n_updates        | 292357   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 632      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8344     |
# |    fps              | 163      |
# |    time_elapsed     | 2608     |
# |    total_timesteps  | 1176526  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.11     |
# |    n_updates        | 292881   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 641      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8348     |
# |    fps              | 163      |
# |    time_elapsed     | 2623     |
# |    total_timesteps  | 1178998  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.78     |
# |    n_updates        | 293499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 632      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8352     |
# |    fps              | 163      |
# |    time_elapsed     | 2626     |
# |    total_timesteps  | 1179572  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 6.19     |
# |    n_updates        | 293642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 625      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8356     |
# |    fps              | 163      |
# |    time_elapsed     | 2637     |
# |    total_timesteps  | 1181267  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.3     |
# |    n_updates        | 294066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 603      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8360     |
# |    fps              | 163      |
# |    time_elapsed     | 2643     |
# |    total_timesteps  | 1182370  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 7.01     |
# |    n_updates        | 294342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 619      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8364     |
# |    fps              | 163      |
# |    time_elapsed     | 2658     |
# |    total_timesteps  | 1184792  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 25.4     |
# |    n_updates        | 294947   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 611      |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8368     |
# |    fps              | 163      |
# |    time_elapsed     | 2671     |
# |    total_timesteps  | 1186941  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.99     |
# |    n_updates        | 295485   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 596      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8372     |
# |    fps              | 163      |
# |    time_elapsed     | 2684     |
# |    total_timesteps  | 1189003  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.57     |
# |    n_updates        | 296000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 607      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8376     |
# |    fps              | 163      |
# |    time_elapsed     | 2703     |
# |    total_timesteps  | 1192119  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.2      |
# |    n_updates        | 296779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 634      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8380     |
# |    fps              | 163      |
# |    time_elapsed     | 2726     |
# |    total_timesteps  | 1195817  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 54       |
# |    n_updates        | 297704   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 638      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8384     |
# |    fps              | 163      |
# |    time_elapsed     | 2737     |
# |    total_timesteps  | 1197703  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.19     |
# |    n_updates        | 298175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 622      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8388     |
# |    fps              | 163      |
# |    time_elapsed     | 2747     |
# |    total_timesteps  | 1199306  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 9.48     |
# |    n_updates        | 298576   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 606      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8392     |
# |    fps              | 163      |
# |    time_elapsed     | 2757     |
# |    total_timesteps  | 1200920  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 8.89     |
# |    n_updates        | 298979   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 606      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8396     |
# |    fps              | 163      |
# |    time_elapsed     | 2785     |
# |    total_timesteps  | 1205528  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 21.2     |
# |    n_updates        | 300131   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 630      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8400     |
# |    fps              | 163      |
# |    time_elapsed     | 2811     |
# |    total_timesteps  | 1209727  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.68     |
# |    n_updates        | 301181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 642      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8404     |
# |    fps              | 163      |
# |    time_elapsed     | 2831     |
# |    total_timesteps  | 1212922  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.87     |
# |    n_updates        | 301980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 644      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8408     |
# |    fps              | 163      |
# |    time_elapsed     | 2848     |
# |    total_timesteps  | 1215739  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.6      |
# |    n_updates        | 302684   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 684      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8412     |
# |    fps              | 163      |
# |    time_elapsed     | 2883     |
# |    total_timesteps  | 1221483  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 39.9     |
# |    n_updates        | 304120   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 677      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8416     |
# |    fps              | 163      |
# |    time_elapsed     | 2892     |
# |    total_timesteps  | 1223012  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 37.9     |
# |    n_updates        | 304502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 680      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8420     |
# |    fps              | 163      |
# |    time_elapsed     | 2905     |
# |    total_timesteps  | 1225119  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.39     |
# |    n_updates        | 305029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 667      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8424     |
# |    fps              | 163      |
# |    time_elapsed     | 2909     |
# |    total_timesteps  | 1225890  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 19       |
# |    n_updates        | 305222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 678      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8428     |
# |    fps              | 163      |
# |    time_elapsed     | 2935     |
# |    total_timesteps  | 1230161  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 29.2     |
# |    n_updates        | 306290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 667      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8432     |
# |    fps              | 163      |
# |    time_elapsed     | 2962     |
# |    total_timesteps  | 1234624  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 34.4     |
# |    n_updates        | 307405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 696      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8436     |
# |    fps              | 163      |
# |    time_elapsed     | 2994     |
# |    total_timesteps  | 1239935  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.67     |
# |    n_updates        | 308733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 677      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8440     |
# |    fps              | 163      |
# |    time_elapsed     | 3008     |
# |    total_timesteps  | 1242173  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.14     |
# |    n_updates        | 309293   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 676      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8444     |
# |    fps              | 163      |
# |    time_elapsed     | 3020     |
# |    total_timesteps  | 1244111  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 5.68     |
# |    n_updates        | 309777   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 667      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8448     |
# |    fps              | 163      |
# |    time_elapsed     | 3030     |
# |    total_timesteps  | 1245725  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 3.83     |
# |    n_updates        | 310181   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Pixel agent — average pipes: 0.0   |   best episode: 0

# %%
def living_bonus(r):
    return r + 0.2

train_env = Monitor(gym.wrappers.TransformReward(FlappyPixelEnv(), living_bonus))
dqn_pix.set_env(train_env)

dqn_pix.exploration_final_eps = 0.10

dqn_pix.learn(total_timesteps=2_000_000,
              reset_num_timesteps=False,
              progress_bar=True)

avg, best = evaluate(dqn_pix)
print(f"\nPixel agent — average pipes: {avg:.1f}   |   best: {best}")
# Out:
#   81% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━ 1,628,353/2,000,000  [ 2:45:13 < 0:37:13 , 166 it/s ]
